# %%
import numpy as np
x = 3.1415926
k = np.round(x,3)
print(k)
# Out:
# 3.142

# %%
import numpy as np
theta = np.linspace(0, 2 * np.pi, 3)
print(theta)
# Out:
# [0.         3.14159265 6.28318531]

# %%
# Circle

import numpy as np
from matplotlib import pyplot as plt

plt.figure(figsize=(6,6))
plt.xlim(0,6)
plt.ylim(0,6)

theta = np.linspace(0, 2 * np.pi, 5)
center = [3,3]
radius = 2
x = center[0] + radius * np.cos(theta)
y = center[1] + radius * np.sin(theta)

print(f"theta = {np.round(theta,2)}")
print(f"x = {np.round(x,2)}")
print(f"y = {np.round(y,2)}")

plt.title('Circle - 4 points')
plt.plot(x, y,"bo-")
plt.show()
# Out:
# theta = [0.   1.57 3.14 4.71 6.28]
# x = [5. 3. 1. 3. 5.]
# y = [3. 5. 3. 1. 3.]

# %%
plt.figure(figsize=(6,6))
plt.xlim(0,6)
plt.ylim(0,6)

theta = np.linspace(0, 2 * np.pi, 9)
center = [3,3]
radius = 2
x = center[0] + radius * np.cos(theta)
y = center[1] + radius * np.sin(theta)

print(f"theta = {np.round(theta,2)}")
print(f"x = {np.round(x,2)}")
print(f"y = {np.round(y,2)}")

plt.title('Circle - 8 points')
plt.plot(x, y,"bo-")
plt.show()
# Out:
# theta = [0.   0.79 1.57 2.36 3.14 3.93 4.71 5.5  6.28]
# x = [5.   4.41 3.   1.59 1.   1.59 3.   4.41 5.  ]
# y = [3.   4.41 5.   4.41 3.   1.59 1.   1.59 3.  ]

# %%
plt.figure(figsize=(6,6))
plt.xlim(0,6)
plt.ylim(0,6)

theta = np.linspace(0, 2 * np.pi, 17)
center = [3,3]
radius = 2
x = center[0] + radius * np.cos(theta)
y = center[1] + radius * np.sin(theta)

print(f"theta = {np.round(theta,2)}")
print(f"x = {np.round(x,2)}")
print(f"y = {np.round(y,2)}")

plt.title('Circle - 16 points')
plt.plot(x, y,"bo-")
plt.show()
# Out:
# theta = [0.   0.39 0.79 1.18 1.57 1.96 2.36 2.75 3.14 3.53 3.93 4.32 4.71 5.11
#  5.5  5.89 6.28]
# x = [5.   4.85 4.41 3.77 3.   2.23 1.59 1.15 1.   1.15 1.59 2.23 3.   3.77
#  4.41 4.85 5.  ]
# y = [3.   3.77 4.41 4.85 5.   4.85 4.41 3.77 3.   2.23 1.59 1.15 1.   1.15
#  1.59 2.23 3.  ]

# %%
plt.figure(figsize=(6,6))
plt.xlim(0,6)
plt.ylim(0,6)

theta = np.linspace(0, 2 * np.pi, 33)
center = [3,3]
radius = 2
x = center[0] + radius * np.cos(theta)
y = center[1] + radius * np.sin(theta)

print(f"theta = {np.round(theta,2)}")
print(f"x = {np.round(x,2)}")
print(f"y = {np.round(y,2)}")

plt.title('Circle - 32 points')
plt.plot(x, y,"ro-")
plt.show()
# Out:
# theta = [0.   0.2  0.39 0.59 0.79 0.98 1.18 1.37 1.57 1.77 1.96 2.16 2.36 2.55
#  2.75 2.95 3.14 3.34 3.53 3.73 3.93 4.12 4.32 4.52 4.71 4.91 5.11 5.3
#  5.5  5.69 5.89 6.09 6.28]
# x = [5.   4.96 4.85 4.66 4.41 4.11 3.77 3.39 3.   2.61 2.23 1.89 1.59 1.34
#  1.15 1.04 1.   1.04 1.15 1.34 1.59 1.89 2.23 2.61 3.   3.39 3.77 4.11
#  4.41 4.66 4.85 4.96 5.  ]
# y = [3.   3.39 3.77 4.11 4.41 4.66 4.85 4.96 5.   4.96 4.85 4.66 4.41 4.11
#  3.77 3.39 3.   2.61 2.23 1.89 1.59 1.34 1.15 1.04 1.   1.04 1.15 1.34
#  1.59 1.89 2.23 2.61 3.  ]

# %%
plt.figure(figsize=(6,6))
plt.xlim(0,6)
plt.ylim(0,6)

theta = np.linspace(0, 2 * np.pi, 65)
center = [3,3]
radius = 2
x = center[0] + radius * np.cos(theta)
y = center[1] + radius * np.sin(theta)

print(f"theta = {np.round(theta,2)}")
print(f"x = {np.round(x,2)}")
print(f"y = {np.round(y,2)}")

plt.title('Circle - 64 points')
plt.plot(x, y,"-")
plt.show()
# Out:
# theta = [0.   0.1  0.2  0.29 0.39 0.49 0.59 0.69 0.79 0.88 0.98 1.08 1.18 1.28
#  1.37 1.47 1.57 1.67 1.77 1.87 1.96 2.06 2.16 2.26 2.36 2.45 2.55 2.65
#  2.75 2.85 2.95 3.04 3.14 3.24 3.34 3.44 3.53 3.63 3.73 3.83 3.93 4.03
#  4.12 4.22 4.32 4.42 4.52 4.61 4.71 4.81 4.91 5.01 5.11 5.2  5.3  5.4
#  5.5  5.6  5.69 5.79 5.89 5.99 6.09 6.19 6.28]
# x = [5.   4.99 4.96 4.91 4.85 4.76 4.66 4.55 4.41 4.27 4.11 3.94 3.77 3.58
#  3.39 3.2  3.   2.8  2.61 2.42 2.23 2.06 1.89 1.73 1.59 1.45 1.34 1.24
#  1.15 1.09 1.04 1.01 1.   1.01 1.04 1.09 1.15 1.24 1.34 1.45 1.59 1.73
#  1.89 2.06 2.23 2.42 2.61 2.8  3.   3.2  3.39 3.58 3.77 3.94 4.11 4.27
#  4.41 4.55 4.66 4.76 4.85 4.91 4.96 4.99 5.  ]
# y = [3.   3.2  3.39 3.58 3.77 3.94 4.11 4.27 4.41 4.55 4.66 4.76 4.85 4.91
#  4.96 4.99 5.   4.99 4.96 4.91 4.85 4.76 4.66 4.55 4.41 4.27 4.11 3.94
#  3.77 3.58 3.39 3.2  3.   2.8  2.61 2.42 2.23 2.06 1.89 1.73 1.59 1.45
#  1.34 1.24 1.15 1.09 1.04 1.01 1.   1.01 1.04 1.09 1.15 1.24 1.34 1.45
#  1.59 1.73 1.89 2.06 2.23 2.42 2.61 2.8  3.  ]

# %%
import numpy as np
from matplotlib import pyplot as plt

theta = np.linspace(0, 2 * np.pi, 9)

x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

plt.plot(x, y,"bo-")
plt.title('Heart Shape - 8 points')
plt.show()

# %%
theta = np.linspace(0, 2 * np.pi, 21)

x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

plt.plot(x, y,"bo-")
plt.title('Heart Shape - 20 points')
plt.show()

# %%
theta = np.linspace(0, 2 * np.pi, 51)

x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

plt.plot(x, y,"bo-")
plt.title('Heart Shape - 50 points')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.xlim(-30,30)
plt.ylim(-30,30)

theta = np.linspace(0, 2 * np.pi, 51)

x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

plt.plot(x, y,"b-")
plt.title('Heart Shape - 50 points')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.xlim(-20,20)
plt.ylim(-20,20)

theta = np.linspace(0, 2 * np.pi, 1001)

x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

plt.plot(x, y,"b-")
plt.title('Heart Shape - 1000 points')
plt.show()
